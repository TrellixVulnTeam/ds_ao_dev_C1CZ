# %%
import pandas as pd
import numpy as np
import re

# %%
#loading the data
data = pd.read_csv('/home/guilherme/Documentos/repos/ds_ao_dev/projeto_webscraping/df_raw.csv')

#delete the columns not necessery
data = data.drop(['Unnamed: 0' ],axis=1)

#product id

data = data.dropna(subset=['product_id'])

#product category

#product name
data['products_name']= data['products_name'].apply(lambda x: x.replace(' ','_').lower())
#products_price

#já fiz o tratamento anteriomente

#product datetime

data['scrapy_datetime']= pd.to_datetime(data['scrapy_datetime'])
#style id

#color id

#color name
data['color_name']= data['color_name'].apply(lambda x: x.replace(' ','_').replace('/','_').lower() if pd.notnull(x) else x)

#Composition

data['Composition']= data['Composition'].where(~data['Composition'].str.contains('Pocket lining:',na=False) ) 

data['Composition']= data['Composition'].where(lambda x: ~x.str.contains('Shell:',na=False) )

data['Composition'] = data['Composition'].where(lambda x: ~x.str.contains('Lining:',na=False) )

#drop duplicates
#first were making drop the that are duplicates (excect the colum Composition), because the colums is duplicate
data= data.drop_duplicates(subset= ['product_id', 'products_category', 'products_name', 'products_price',
       'scrapy_datetime', 'stlye_id', 'color_id', 'color_name'],keep='last')

   
#reset index
data = data.reset_index(drop=True)


#break composition by comma (separando as composições dos materiais por coluna)
df1 = data['Composition'].str.split(',',expand=True)


#Cotton| Spandex | Polyester |  Elastomultiester

data
# Out:
#      product_id products_category        products_name  products_price  \
# 0    1024256001    men_jeans_slim           slim_jeans           19.99
# 1    1024256001    men_jeans_slim           slim_jeans           19.99
# 2    1024256001    men_jeans_slim           slim_jeans           19.99
# 3    1024256001    men_jeans_slim           slim_jeans           19.99
# 4    1024256001    men_jeans_slim           slim_jeans           19.99
# ..          ...               ...                  ...             ...
# 576   814631018    men_jeans_slim  freefit®_slim_jeans           49.99
# 577   814631018    men_jeans_slim  freefit®_slim_jeans           49.99
# 578   814631018    men_jeans_slim  freefit®_slim_jeans           49.99
# 579   814631018    men_jeans_slim  freefit®_slim_jeans           49.99
# 580   814631018    men_jeans_slim  freefit®_slim_jeans           49.99
#
#               scrapy_datetime  stlye_id  color_id           color_name  \
# 0   2022-04-24 11:00:00-21:30   1024256         1      dark_denim_blue
# 1   2022-04-24 11:00:00-21:30   1024256         1                black
# 2   2022-04-24 11:00:00-21:30   1024256         1     light_denim_blue
# 3   2022-04-24 11:00:00-21:30   1024256         1           denim_blue
# 4   2022-04-24 11:00:00-21:30   1024256         1            dark_blue
# ..                        ...       ...       ...                  ...
# 576 2022-04-24 11:00:00-21:30    814631        18           light_gray
# 577 2022-04-24 11:00:00-21:30    814631        18  black_no_fade_black
# 578 2022-04-24 11:00:00-21:30    814631        18            dark_blue
# 579 2022-04-24 11:00:00-21:30    814631        18                white
# 580 2022-04-24 11:00:00-21:30    814631        18                 gray
#
#                                      Composition
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 576  Cotton 90%, Elastomultiester 8%, Spandex 2%
# 577  Cotton 90%, Elastomultiester 8%, Spandex 2%
# 578  Cotton 90%, Elastomultiester 8%, Spandex 2%
# 579  Cotton 90%, Elastomultiester 8%, Spandex 2%
# 580  Cotton 90%, Elastomultiester 8%, Spandex 2%
#
# [581 rows x 9 columns]

# %%
df1[df1[1].isna()]
# Out:
#        0     1     2
# 0    NaN  None  None
# 1    NaN  None  None
# 2    NaN  None  None
# 3    NaN  None  None
# 4    NaN  None  None
# ..   ...   ...   ...
# 567  NaN  None  None
# 568  NaN  None  None
# 569  NaN  None  None
# 570  NaN  None  None
# 571  NaN  None  None
#
# [442 rows x 3 columns]

# %%
data.loc[576,:]
# Out:
# product_id                                             814631018
# products_category                                 men_jeans_slim
# products_name                                freefit®_slim_jeans
# products_price                                             49.99
# scrapy_datetime                        2022-04-24 11:00:00-21:30
# stlye_id                                                  814631
# color_id                                                      18
# color_name                                            light_gray
# Composition          Cotton 90%, Elastomultiester 8%, Spandex 2%
# Name: 576, dtype: object

# %%
data[data['product_id']==  814631018]
# Out:
#      product_id products_category        products_name  products_price  \
# 572   814631018    men_jeans_slim  freefit®_slim_jeans           49.99
# 573   814631018    men_jeans_slim  freefit®_slim_jeans           49.99
# 574   814631018    men_jeans_slim  freefit®_slim_jeans           49.99
# 575   814631018    men_jeans_slim  freefit®_slim_jeans           49.99
# 576   814631018    men_jeans_slim  freefit®_slim_jeans           49.99
# 577   814631018    men_jeans_slim  freefit®_slim_jeans           49.99
# 578   814631018    men_jeans_slim  freefit®_slim_jeans           49.99
# 579   814631018    men_jeans_slim  freefit®_slim_jeans           49.99
# 580   814631018    men_jeans_slim  freefit®_slim_jeans           49.99
#
#               scrapy_datetime  stlye_id  color_id           color_name  \
# 572 2022-04-24 11:00:00-21:30    814631        18      dark_denim_blue
# 573 2022-04-24 11:00:00-21:30    814631        18     light_denim_blue
# 574 2022-04-24 11:00:00-21:30    814631        18            dark_gray
# 575 2022-04-24 11:00:00-21:30    814631        18      pale_denim_blue
# 576 2022-04-24 11:00:00-21:30    814631        18           light_gray
# 577 2022-04-24 11:00:00-21:30    814631        18  black_no_fade_black
# 578 2022-04-24 11:00:00-21:30    814631        18            dark_blue
# 579 2022-04-24 11:00:00-21:30    814631        18                white
# 580 2022-04-24 11:00:00-21:30    814631        18                 gray
#
#                                      Composition
# 572  Cotton 90%, Elastomultiester 8%, Spandex 2%
# 573  Cotton 90%, Elastomultiester 8%, Spandex 2%
# 574  Cotton 90%, Elastomultiester 8%, Spandex 2%
# 575  Cotton 90%, Elastomultiester 8%, Spandex 2%
# 576  Cotton 90%, Elastomultiester 8%, Spandex 2%
# 577  Cotton 90%, Elastomultiester 8%, Spandex 2%
# 578  Cotton 90%, Elastomultiester 8%, Spandex 2%
# 579  Cotton 90%, Elastomultiester 8%, Spandex 2%
# 580  Cotton 90%, Elastomultiester 8%, Spandex 2%

# %%
df1[2].unique()
# Out:
# array([None, ' Spandex 1%', nan, ' Spandex 2%'], dtype=object)

# %%
#Cotton| Spandex | Polyester |  Elastomultiester
#2 etapa
#definir as colunas (organizando as colunas por máteria-prima)

#criando Dataframe vazio com o mesmo tamanho do dataframe original para prencher com as respectivas composições
df_ref = pd.DataFrame(index=np.arange(len(data) ),columns=['cotton','spandex','polyester','elastomultiester'])

#cotton
#pegando a coluna da composição cotton
df_cotton = df1[0]

#colocando o nome na coluna 
df_cotton.name = 'cotton'
#mesclando com a tabela vazia 
df_ref = pd.concat([df_ref,df_cotton],axis=1)

#dropando as colunas duplicadas
df_ref= df_ref.iloc[:,~df_ref.columns.duplicated(keep='last')]

df_ref['cotton'] = df_ref['cotton'].fillna( 'Cotton 0%' )

#polyester 

#adicionando as coluna da composição Polyester
df_polyester =df1[1].where(lambda x: x.str.contains('Polyester',na=True))

#renomeando a coluna
df_polyester.name= 'polyester'


df_ref= pd.concat([df_ref,df_polyester],axis=1)

#dropando as colunas duplicadas
df_ref= df_ref.iloc[:,~df_ref.columns.duplicated(keep='last')]

#Elastomultiester

#coletando apenas a composição elastano
df_elastomultiester =df1[1].where(lambda x: x.str.contains('Elastomultiester',na=True))

#renomenado a coluna eslastano
df_elastomultiester.name= 'elastomultiester'


#mesclando com df_ref vazio e com a mesma quantidade de linhas que há no index
df_ref= pd.concat([df_ref,df_elastomultiester],axis=1)

#dropando as colunas duplicadas
df_ref= df_ref.iloc[:,~df_ref.columns.duplicated(keep='last')]

#Spandex

#coletando composição spandex da segunda coluna df1

df_spandex= df1[1].where(lambda x: x.str.contains('Spandex',na=True))

df_spandex.name = 'spandex'

#combine from spandex botth columns 1 and 2

df_spandex = df_spandex.combine_first(df1[2])


df_ref= pd.concat([df_ref,df_spandex],axis=1)

df_ref= df_ref.iloc[:,~df_ref.columns.duplicated(keep='last')]

#df_ref= df_ref['spandex'].fillna('Spandex 0%')

#coletando composição spandex da terceira coluna do df1

#df_spandex_2= df1[2].where(lambda x: x.str.contains('Spandex',na=True))
             
#df_spandex_2.name= 'spandex'

#df_ref= pd.concat([df_ref,df_spandex_2],axis=1)

#df_ref= df_ref.iloc[:,~df_ref.columns.duplicated(keep='last')]



#final join

data= pd.concat([data,df_ref],axis=1)

#coletando apenas os numeros e transformando em números inteiros

#format composition data

#cotton
data['cotton']= data['cotton'].apply(lambda x: int(re.search('\d+',x ).group(0))/100 if pd.notnull(x) else x)

#spandex
data['spandex'] =data['spandex'].apply(lambda x: int(re.search('\d+', x).group(0)) /100 if pd.notnull(x) else x)

#polyester
data['polyester']= data['polyester'].apply(lambda x: int(re.search('\d+', x).group(0))/100 if pd.notnull(x) else x)

#elastomultiester
data['elastomultiester']=data['elastomultiester'].apply(lambda x: int(re.search('\d+', x).group(0)) /100 if pd.notnull(x) else x)

# %%
# Out:
# 0    [nan, Cotton 98%, Cotton 99%, Cotton 93%, Cott...
# 1    [None,  Spandex 2%,  Spandex 1%,  Polyester 6%...
# 2                [None,  Spandex 1%, nan,  Spandex 2%]
# dtype: object

# %%
# Out:
# array([None, ' Spandex 2%', ' Spandex 1%', ' Polyester 6%',
#        ' Polyester 19%', nan, ' Polyester 21%', ' Elastomultiester 8%'],
#       dtype=object)

# %%
df_elastomultiester.unique()
# Out:
# array([None, nan, ' Elastomultiester 8%'], dtype=object)

# %%
data.sample(20)
# Out:
#      product_id  products_category          products_name  products_price  \
# 74    690449036   men_jeans_ripped           skinny_jeans           39.99
# 47    979945009    men_jeans_loose            loose_jeans           29.99
# 235  1004199004   men_jeans_skinny   skinny_cropped_jeans           29.99
# 477   811993037  men_jeans_regular          regular_jeans           29.99
# 144   690449056   men_jeans_ripped           skinny_jeans           39.99
# 343   938875012     men_jeans_slim     slim_tapered_jeans           39.99
# 82    979945001    men_jeans_loose            loose_jeans           29.99
# 124   690449043   men_jeans_ripped           skinny_jeans           39.99
# 116  1024256005     men_jeans_slim             slim_jeans           19.99
# 552  1018704002  men_jeans_relaxed  relaxed_pull-on_jeans           24.99
# 238  1004199004   men_jeans_skinny   skinny_cropped_jeans           29.99
# 152   690449056   men_jeans_ripped           skinny_jeans           39.99
# 237  1004199004   men_jeans_skinny   skinny_cropped_jeans           29.99
# 457   875105016  men_jeans_relaxed          relaxed_jeans           29.99
# 390  1008110003     men_jeans_slim    freefit®_slim_jeans           49.99
# 488   938875014     men_jeans_slim     slim_tapered_jeans           39.99
# 89    690449051   men_jeans_ripped           skinny_jeans           39.99
# 330   985159007   men_jeans_skinny           skinny_jeans           19.99
# 566  1048642002  men_jeans_regular  regular_bootcut_jeans           39.99
# 291  1024256006     men_jeans_slim             slim_jeans           19.99
#
#               scrapy_datetime  stlye_id  color_id               color_name  \
# 74  2022-04-24 11:00:00-21:30    690449        36                     gray
# 47  2022-04-24 11:00:00-21:30    979945         9               denim_blue
# 235 2022-04-24 11:00:00-21:30   1004199         4         light_denim_blue
# 477 2022-04-24 11:00:00-21:30    811993        37                dark_blue
# 144 2022-04-24 11:00:00-21:30    690449        56        dark_blue_trashed
# 343 2022-04-24 11:00:00-21:30    938875        12                    white
# 82  2022-04-24 11:00:00-21:30    979945         1               denim_blue
# 124 2022-04-24 11:00:00-21:30    690449        43               denim_blue
# 116 2022-04-24 11:00:00-21:30   1024256         5          dark_denim_blue
# 552 2022-04-24 11:00:00-21:30   1018704         2         light_denim_blue
# 238 2022-04-24 11:00:00-21:30   1004199         4                    white
# 152 2022-04-24 11:00:00-21:30    690449        56         light_denim_blue
# 237 2022-04-24 11:00:00-21:30   1004199         4               denim_blue
# 457 2022-04-24 11:00:00-21:30    875105        16          dark_denim_blue
# 390 2022-04-24 11:00:00-21:30   1008110         3      black_no_fade_black
# 488 2022-04-24 11:00:00-21:30    938875        14         light_denim_blue
# 89  2022-04-24 11:00:00-21:30    690449        51  dark_denim_blue_trashed
# 330 2022-04-24 11:00:00-21:30    985159         7                dark_gray
# 566 2022-04-24 11:00:00-21:30   1048642         2              denim_black
# 291 2022-04-24 11:00:00-21:30   1024256         6                dark_blue
#
#                 Composition  cotton  polyester  elastomultiester  spandex
# 74                      NaN     NaN        NaN               NaN      NaN
# 47                      NaN     NaN        NaN               NaN      NaN
# 235                     NaN     NaN        NaN               NaN      NaN
# 477  Cotton 98%, Spandex 2%    0.98        NaN               NaN     0.02
# 144                     NaN     NaN        NaN               NaN      NaN
# 343                     NaN     NaN        NaN               NaN      NaN
# 82                      NaN     NaN        NaN               NaN      NaN
# 124                     NaN     NaN        NaN               NaN      NaN
# 116                     NaN     NaN        NaN               NaN      NaN
# 552                     NaN     NaN        NaN               NaN      NaN
# 238  Cotton 99%, Spandex 1%    0.99        NaN               NaN     0.01
# 152                     NaN     NaN        NaN               NaN      NaN
# 237  Cotton 99%, Spandex 1%    0.99        NaN               NaN     0.01
# 457                     NaN     NaN        NaN               NaN      NaN
# 390                     NaN     NaN        NaN               NaN      NaN
# 488                     NaN     NaN        NaN               NaN      NaN
# 89                      NaN     NaN        NaN               NaN      NaN
# 330                     NaN     NaN        NaN               NaN      NaN
# 566                     NaN     NaN        NaN               NaN      NaN
# 291                     NaN     NaN        NaN               NaN      NaN

# %%
df_spandex.loc[df_spandex!= df_spandex.isna().sum()]
# Out:
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
#           ...
# 576     Spandex 2%
# 577     Spandex 2%
# 578     Spandex 2%
# 579     Spandex 2%
# 580     Spandex 2%
# Name: spandex, Length: 581, dtype: object

# %%
df_spandex.head(22)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# Name: spandex, dtype: object
